# %%
num1 = 23
num2 = 43
sum = num1 + num2
print(sum)
# Out:
# 66

# %% [markdown]
# This is a sample Jupyter notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as skl
import numpy as np

# %% [markdown]
# ## MY DATA SCIENCE
# Testing Conda environment, Jupyter Notebook, and Python Libraries

# %% [markdown]
# ![Data Science Framework](assets/images/ds_framework.PNG)
